# %%
from PIL import Image
import numpy as np
import os
from glob import glob
import cv2

# %%
# 이미지 가져오기
image_list = glob('./data/image/*')

# 이미지 한 개 가져오기
image = image_list[0]

image
# Out:
# './data/image/036_5e0af3bf.jpg'

# %%
Image.open(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=474x474>

# %%
img = Image.open(image)
img = np.asarray(img)
img
# Out:
# array([[[40, 44, 55],
#         [40, 44, 55],
#         [40, 44, 55],
#         ...,
#         [43, 47, 59],
#         [43, 47, 59],
#         [43, 47, 59]],
#
#        [[39, 43, 54],
#         [39, 43, 54],
#         [39, 43, 54],
#         ...,
#         [43, 47, 59],
#         [43, 47, 59],
#         [43, 47, 59]],
#
#        [[38, 42, 53],
#         [38, 42, 53],
#         [38, 42, 53],
#         ...,
#         [43, 47, 59],
#         [43, 47, 59],
#         [43, 47, 59]],
#
#        ...,
#
#        [[29, 33, 45],
#         [30, 34, 46],
#         [32, 36, 48],
#         ...,
#         [35, 37, 49],
#         [34, 37, 46],
#         [34, 37, 46]],
#
#        [[66, 70, 82],
#         [30, 34, 46],
#         [34, 38, 50],
#         ...,
#         [37, 40, 49],
#         [33, 36, 45],
#         [68, 71, 80]],
#
#        [[66, 70, 82],
#         [30, 34, 46],
#         [34, 38, 50],
#         ...,
#         [37, 40, 49],
#         [33, 36, 45],
#         [68, 71, 80]]], dtype=uint8)

# %%
# 입력 이미지의 복사본 생성
vis_img = img.copy().astype(np.uint8)
vis_img
# Out:
# array([[[40, 44, 55],
#         [40, 44, 55],
#         [40, 44, 55],
#         ...,
#         [43, 47, 59],
#         [43, 47, 59],
#         [43, 47, 59]],
#
#        [[39, 43, 54],
#         [39, 43, 54],
#         [39, 43, 54],
#         ...,
#         [43, 47, 59],
#         [43, 47, 59],
#         [43, 47, 59]],
#
#        [[38, 42, 53],
#         [38, 42, 53],
#         [38, 42, 53],
#         ...,
#         [43, 47, 59],
#         [43, 47, 59],
#         [43, 47, 59]],
#
#        ...,
#
#        [[29, 33, 45],
#         [30, 34, 46],
#         [32, 36, 48],
#         ...,
#         [35, 37, 49],
#         [34, 37, 46],
#         [34, 37, 46]],
#
#        [[66, 70, 82],
#         [30, 34, 46],
#         [34, 38, 50],
#         ...,
#         [37, 40, 49],
#         [33, 36, 45],
#         [68, 71, 80]],
#
#        [[66, 70, 82],
#         [30, 34, 46],
#         [34, 38, 50],
#         ...,
#         [37, 40, 49],
#         [33, 36, 45],
#         [68, 71, 80]]], dtype=uint8)

# %%
# 파싱 주석을 복사하여 uint8 형식으로 변환
vis_parsing_anno = parsing_anno.copy().astype(np.uint8)
